# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Titanic-Dataset.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr(numeric_only=True).abs()[["Survived"]]
# Out:
#              Survived
# PassengerId  0.005007
# Survived     1.000000
# Pclass       0.338481
# Sex          0.543351
# Age          0.077221
# SibSp        0.035322
# Parch        0.081629
# Fare         0.257307

# %%
data['Relatives'] = data.apply (lambda row: int((row['SibSp'] + row['Parch']) > 0), axis=1)
data.corr(numeric_only=True).abs()[["Survived"]]
# Out:
#              Survived
# PassengerId  0.005007
# Survived     1.000000
# Pclass       0.338481
# Sex          0.543351
# Age          0.077221
# SibSp        0.035322
# Parch        0.081629
# Fare         0.257307
# Relatives    0.203367

# %%
data = data[['Sex', 'Pclass','Age','Relatives','Fare','Survived']].dropna()

# %%
#TRAINING THE MODEL

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['Sex','Pclass','Age','Relatives','Fare']], data.Survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#ACCURACY OF THE BUILT MODEL

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7482517482517482

# %%
#PREDICTION OF SURVIVAL

# %%
reply='y'

# %%
while reply == 'y':
    print("KINDLY PROVIDE DETAILS HERE")
    PCLASS = int(input("Passenger's Class(1/2/3):")) 
    SEX = int(input("male(1) or female(0):"))  
    AGE = int(input("Passenger's age:"))
    SS = int(input("No. of siblings/spouses aboard:"))
    PC = int(input("No. of parents/children aboard:"))  
    data_to_predict = [PCLASS, SEX, AGE, SS, PC]
    data_to_predict_2d = np.array(data_to_predict).reshape(1, -1)
    predictions = model.predict(data_to_predict_2d)
    if predictions == 1:  
        print("prediction: SURVIVED")
    else:
        print("prediction: NOT SURVIVED")
    reply = input("continue with other data(y/n):")
